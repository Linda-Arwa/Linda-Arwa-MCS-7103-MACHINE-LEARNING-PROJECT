# %%
# Load necessary packages
import numpy as np
import pandas as pd
import matplotlib as mpl
from plotnine import *

# Visualization modules
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

import warnings
warnings.filterwarnings("ignore")

# Module for saving model
import joblib

# Set seed for reproducibility 
SEED = 42

# %%
# Load the dataset
df = pd.read_csv('transactions_train.csv')
print(f"Original Shape: {df.shape}")
df.head(10)
# Out:
# Original Shape: (6351193, 10)
#    step      type    amount     nameOrig  oldbalanceOrig  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.00       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.00        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.00            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.00            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.00        29885.86
# 5     1   PAYMENT   7817.71    C90045638        53860.00        46042.29
# 6     1   PAYMENT   7107.77   C154988899       183195.00       176087.23
# 7     1   PAYMENT   7861.64  C1912850431       176087.23       168225.59
# 8     1   PAYMENT   4024.36  C1265012928         2671.00            0.00
# 9     1     DEBIT   5337.77   C712410124        41720.00        36382.23
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud
# 0  M1979787155             0.0            0.00        0
# ...

# %%
#checking columns
df.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrig',
#        'newbalanceOrig', 'nameDest', 'oldbalanceDest', 'newbalanceDest',
#        'isFraud'],
#       dtype='object')

# %%
#Dropping all the unnecessary columns
df_model = df.drop(["step", "nameOrig", "nameDest"], axis = 1)

# %%
#colums after dropping unwanted
df_model.head()
# Out:
#        type    amount  oldbalanceOrig  newbalanceOrig  oldbalanceDest  \
# 0   PAYMENT   9839.64        170136.0       160296.36             0.0
# 1   PAYMENT   1864.28         21249.0        19384.72             0.0
# 2  TRANSFER    181.00           181.0            0.00             0.0
# 3  CASH_OUT    181.00           181.0            0.00         21182.0
# 4   PAYMENT  11668.14         41554.0        29885.86             0.0
#
#    newbalanceDest  isFraud
# 0             0.0        0
# 1             0.0        0
# 2             0.0        1
# 3             0.0        1
# 4             0.0        0

# %%
#Checking fraud transactions

df["isFraud"].value_counts()
# Out:
# isFraud
# 0    6343476
# 1       7717
# Name: count, dtype: int64

# %%
#setting categorical and numerical data

categorical = ["type"]
numeric = ["amount", "oldbalanceOrig", "newbalanceOrig", "oldbalanceDest", "newbalanceDest"]

# %%
df_model.head()
# Out:
#        type    amount  oldbalanceOrig  newbalanceOrig  oldbalanceDest  \
# 0   PAYMENT   9839.64        170136.0       160296.36             0.0
# 1   PAYMENT   1864.28         21249.0        19384.72             0.0
# 2  TRANSFER    181.00           181.0            0.00             0.0
# 3  CASH_OUT    181.00           181.0            0.00         21182.0
# 4   PAYMENT  11668.14         41554.0        29885.86             0.0
#
#    newbalanceDest  isFraud
# 0             0.0        0
# 1             0.0        0
# 2             0.0        1
# 3             0.0        1
# 4             0.0        0

# %%
# Save the transformed dataset
df_model.to_csv('C:/Users/localadmin/Desktop/ML/Final Sem Project/Linda Arwa Project/df_model.csv', index=False)
